# %% [markdown]
# Do method comparison like:

# %% [markdown]
# ![image.png](attachment:4c847480-58b4-4a1b-af33-5817ef17f4b0.png)

# %% [markdown]
# From https://arxiv.org/pdf/1907.06347.pdf

# %% [markdown]
# In particular it would be interesting to see if any of the methods correlate with the optimal beam_search method.
